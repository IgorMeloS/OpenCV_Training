# %% [markdown]
# # Contours

# %% [markdown]
# ## Importing libraries

# %%
from __future__ import print_function
import numpy as np
import cv2
import imutils
import mahotas
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load image from disk

# %%
img = cv2.imread("images/but_foot.jpg")

# %%
plt.figure(figsize=(15,10))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Countours

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # converting into gray scale
gray = gray.astype(np.uint8)
eq = cv2.equalizeHist(gray)
blurred = cv2.GaussianBlur(eq, (9,9), 0) 
edged = cv2.Canny(blurred, 45, 216, L2gradient = True, apertureSize = 3)
(T, thresh) = cv2.threshold(edged, 200, 255, cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
plt.title("Gray scale")
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
plt.subplot(3,2,2)
plt.title("Histogram Equalization")
plt.imshow(cv2.cvtColor(eq1, cv2.COLOR_BGR2RGB))
plt.subplot(3,2,3)
plt.title("Blurred")
plt.imshow(cv2.cvtColor(blurred, cv2.COLOR_BGR2RGB))
plt.subplot(3,2,4)
plt.title("Edge detection")
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))
plt.subplot(3,2,5)
plt.title("Threshold")
plt.imshow(cv2.cvtColor(thresh, cv2.COLOR_BGR2RGB))
plt.show()

# %%
(T, thresh) = cv2.threshold(edged, 200, 255, cv2.THRESH_BINARY)
#thresh = cv2.adaptiveThreshold(edged,215,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV,3,3)

# %%
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)

# %%
print("I count {} coins in this image".format(len(cnts)))
# Out:
# I count 13 coins in this image

# %%
coins = img.copy()
cv2.drawContours(coins, cnts, -1, (0, 255, 0), 2)
# Out:
# array([[[242, 249, 252],
#         [241, 248, 251],
#         [241, 248, 251],
#         ...,
#         [178, 191, 207],
#         [178, 191, 207],
#         [178, 191, 207]],
#
#        [[242, 249, 252],
#         [241, 248, 251],
#         [241, 248, 251],
#         ...,
#         [179, 192, 208],
#         [178, 191, 207],
#         [178, 191, 207]],
#
#        [[242, 249, 252],
#         [241, 248, 251],
#         [241, 248, 251],
#         ...,
#         [178, 191, 207],
#         [178, 191, 207],
#         [177, 190, 206]],
#
#        ...,
#
#        [[241, 247, 246],
#         [241, 247, 246],
#         [241, 247, 246],
#         ...,
#         [165, 178, 192],
#         [166, 179, 193],
#         [166, 179, 193]],
#
#        [[241, 247, 246],
#         [241, 247, 246],
#         [241, 247, 246],
#         ...,
#         [166, 178, 188],
#         [166, 178, 188],
#         [166, 178, 188]],
#
#        [[243, 249, 248],
#         [242, 248, 247],
#         [241, 247, 246],
# ...

# %%
plt.figure(figsize=(15,10))
plt.imshow(cv2.cvtColor(coins, cv2.COLOR_BGR2RGB))
plt.show()
